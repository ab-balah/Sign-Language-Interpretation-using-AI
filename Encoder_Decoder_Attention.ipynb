# %% [markdown]
# Abderrahmane Balah - 201932370 - Section 1

# %% [markdown]
# This notebook has code related to developing an Encoder-Decoder model (with attention). The second notebook has the encoder-decoder model without attention.

# %% [markdown]
# # Attention Based ENCODER-DECODER for Sign Language Interpretation

# %% [markdown]
# [20 points] Develop an encoder-decoder model with attention to recognize the sign video (video captioning)

# %% [markdown]
# #Unzipping Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/ICS471/Assignment3/Assignment03.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0028.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0029.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0030.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0031.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0032.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0033.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0034.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0035.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0036.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0037.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0038.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0039.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0040.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0041.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0042.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0043.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0044.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0045.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0046.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0047.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0048.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0049.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0050.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0051.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0052.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0053.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0054.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0055.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0056.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0057.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0058.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0059.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0060.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0061.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0062.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0063.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0064.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0065.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0066.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0067.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0068.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0069.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0070.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0071.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0072.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0073.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0074.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0075.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0076.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0077.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0078.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0079.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_02)_c/02_0009_(27_02_21_20_43_02)_c_0080.jpg
#    creating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0001.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0002.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0003.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0004.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0005.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0006.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0007.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0008.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0009.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0010.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0011.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0012.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0013.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0014.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0015.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0016.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0017.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0018.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0019.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0020.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0021.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0022.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0028.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0029.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0030.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0031.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0032.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0033.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0034.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0035.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0036.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0037.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0038.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0039.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0040.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0041.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0042.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0043.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0044.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0045.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0046.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0047.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0048.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0049.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0050.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0051.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0052.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0053.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0054.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0055.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0056.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0057.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0058.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0059.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0060.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0061.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0062.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0063.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0064.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0065.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0066.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0067.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0068.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0069.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0070.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0071.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0072.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0073.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0074.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0075.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0076.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0077.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0078.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0079.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_07)_c/02_0009_(27_02_21_20_43_07)_c_0080.jpg
#    creating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0001.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0002.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0003.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0004.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0005.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0006.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0007.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0008.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0009.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0010.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0011.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0012.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0013.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0014.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0015.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0016.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0017.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0018.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0019.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0020.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0021.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0022.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0028.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0029.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0030.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0031.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0032.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0033.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0034.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0035.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0036.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0037.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0038.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0039.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0040.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0041.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0042.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0043.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0044.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0045.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0046.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0047.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0048.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0049.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0050.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0051.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0052.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0053.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0054.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0055.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0056.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0057.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0058.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0059.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0060.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0061.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0062.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0063.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0064.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0065.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0066.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0067.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0068.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0069.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0070.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0071.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0072.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0073.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0074.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0075.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0076.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0077.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0078.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0079.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_11)_c/02_0009_(27_02_21_20_43_11)_c_0080.jpg
#    creating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0001.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0002.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0003.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0004.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0005.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0006.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0007.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0008.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0009.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0010.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0011.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0012.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0013.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0014.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0015.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0016.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0017.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0018.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0019.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0020.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0021.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0022.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0028.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0029.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0030.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0031.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0032.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0033.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0034.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0035.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0036.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0037.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0038.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0039.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0040.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0041.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0042.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0043.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0044.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0045.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0046.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0047.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0048.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0049.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0050.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0051.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0052.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0053.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0054.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0055.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0056.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0057.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0058.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0059.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0060.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0061.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0062.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0063.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0064.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0065.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0066.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0067.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0068.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0069.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0070.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0071.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0072.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0073.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0074.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0075.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0076.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0077.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0078.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0079.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_16)_c/02_0009_(27_02_21_20_43_16)_c_0080.jpg
#    creating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0001.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0002.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0003.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0004.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0005.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0006.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0007.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0008.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0009.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0010.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0011.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0012.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0013.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0014.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0015.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0016.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0017.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0018.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0019.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0020.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0021.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0022.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0028.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0029.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0030.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0031.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0032.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0033.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0034.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0035.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0036.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0037.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0038.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0039.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0040.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0041.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0042.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0043.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0044.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0045.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0046.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0047.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0048.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0049.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0050.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0051.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0052.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0053.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0054.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0055.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0056.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0057.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0058.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0059.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0060.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0061.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0062.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0063.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0064.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0065.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0066.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0067.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0068.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0069.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0070.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0071.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0072.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0073.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0074.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0075.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0076.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0077.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0078.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0079.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_20)_c/02_0009_(27_02_21_20_43_20)_c_0080.jpg
#    creating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0001.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0002.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0003.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0004.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0005.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0006.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0007.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0008.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0009.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0010.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0011.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0012.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0013.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0014.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0015.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0016.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0017.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0018.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0019.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0020.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0021.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0022.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0023.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0024.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0025.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0026.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0027.jpg
#   inflating: /content/Assignment03/train/0009/02_0009_(27_02_21_20_43_25)_c/02_0009_(27_02_21_20_43_25)_c_0028.jpg
# ...
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0025.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0026.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0027.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0028.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0029.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0030.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0031.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0032.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0033.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0034.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0035.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0036.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0037.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0038.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0039.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0040.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0041.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0042.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0043.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0044.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0045.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0046.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0047.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0048.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0049.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0050.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0051.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0052.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0053.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0054.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0055.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0056.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0057.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0058.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0059.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0060.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0061.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0062.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0063.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0064.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0065.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0066.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0067.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0068.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0069.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0070.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0071.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0072.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0073.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0074.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0075.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0076.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0077.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0078.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0079.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_46_58)_c/02_0010_(27_02_21_20_46_58)_c_0080.jpg
#    creating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0001.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0002.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0003.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0004.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0005.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0006.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0007.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0008.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0009.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0010.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0011.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0012.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0013.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0014.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0015.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0016.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0017.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0018.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0019.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0020.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0021.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0022.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0023.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0024.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0025.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0026.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0027.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0028.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0029.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0030.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0031.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0032.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0033.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0034.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0035.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0036.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0037.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0038.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0039.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0040.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0041.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0042.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0043.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0044.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0045.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0046.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0047.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0048.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0049.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0050.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0051.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0052.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0053.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0054.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0055.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0056.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0057.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0058.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0059.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0060.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0061.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0062.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0063.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0064.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0065.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0066.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0067.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0068.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0069.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0070.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0071.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0072.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0073.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0074.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0075.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0076.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0077.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0078.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0079.jpg
#   inflating: /content/Assignment03/train/0010/02_0010_(27_02_21_20_47_01)_c/02_0010_(27_02_21_20_47_01)_c_0080.jpg

# %% [markdown]
# # Data Preprocessing

# %%
import torch
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from torchvision import transforms
from PIL import Image
import os

class SignLanguageDataset(Dataset):
    def __init__(self, root_dir, caption_mapping, vocab, transform=None, data=None):
        self.root_dir = root_dir
        self.caption_mapping = caption_mapping
        self.vocab = vocab
        self.transform = transform
        if(data is None):
          self.data = self._load_data()
        else:
          self.data = data

    def _load_data(self):
        data = []
        for folder_name in sorted(os.listdir(self.root_dir)):
            folder_path = os.path.join(self.root_dir, folder_name)
            for video_folder in os.listdir(folder_path):
                video_folder_path = os.path.join(folder_path, video_folder)
                frames = [os.path.join(video_folder_path, frame) for frame in sorted(os.listdir(video_folder_path))]
                caption = self.caption_mapping[folder_name]
                numericalized_caption = numericalize(caption, self.vocab)
                data.append((frames, numericalized_caption))
        return data

    def __getitem__(self, idx):
        frames_paths, numericalized_caption = self.data[idx]
        frames = [Image.open(frame_path).convert('RGB') for frame_path in frames_paths]

        if self.transform:
            frames = [self.transform(frame) for frame in frames]
        else:
            to_tensor = transforms.ToTensor()
            frames = [to_tensor(frame) for frame in frames]

        frames_tensor = torch.stack(frames)
        caption_tensor = torch.tensor(numericalized_caption)
        return frames_tensor, caption_tensor

    def __len__(self):
        return len(self.data)

    def subset(self, indices):
        subset_data = [self.data[i] for i in indices]
        return SignLanguageDataset(self.root_dir, self.caption_mapping, self.vocab, self.transform, subset_data)

def load_captions(captions_file):
    with open(captions_file, 'r', encoding='utf-8') as file:
        captions = file.read().splitlines()
    # Create a mapping from folder number to caption
    caption_mapping = {str(i).zfill(4): caption for i, caption in enumerate(captions, 1)}
    return caption_mapping

def build_vocab(captions):
    tokenized_captions = [caption.lower().split() for caption in captions]
    vocab = build_vocab_from_iterator(tokenized_captions, specials=['<unk>', '<pad>', '<sos>', '<eos>'])
    vocab.set_default_index(vocab['<unk>'])
    return vocab

def numericalize(caption, vocab):
    return [vocab['<sos>']] + [vocab[token] for token in caption.lower().split()] + [vocab['<eos>']]

def collate_fn(batch):
    # Separate frames and captions
    frames, captions = zip(*batch)
    # Pad the captions to the same length
    captions_padded = pad_sequence(captions, batch_first=True, padding_value=vocab['<eos>'])
    # Stack frames
    frames_stacked = torch.stack(frames)
    return frames_stacked, captions_padded

# Load the data with the collate function
def get_data_loader(root_dir, caption_mapping, vocab, batch_size, transform, shuffle=True, num_workers=4):
    dataset = SignLanguageDataset(root_dir=root_dir, caption_mapping=caption_mapping, vocab=vocab, transform=transform)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, collate_fn=collate_fn)

# %%
caption_mapping = load_captions('/content/Assignment03/groundTruth.txt')
all_captions = list(caption_mapping.values())
vocab = build_vocab(all_captions)

train_transform = transforms.Compose([
    transforms.Resize((256, 256)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  
])
test_transform = transforms.Compose([
    transforms.Resize((256, 256)), 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  
])

# Test data loader
test_data_loader = get_data_loader(
    root_dir='/content/Assignment03/test/',
    caption_mapping=caption_mapping,
    vocab=vocab,
    batch_size=1,
    transform=test_transform,
    shuffle=True,
    num_workers=2
)

# %%
from sklearn.model_selection import train_test_split

full_test_dataset = SignLanguageDataset(root_dir='/content/Assignment03/train/',
                                        caption_mapping=caption_mapping,
                                        vocab=vocab,
                                        transform=train_transform)


captions = [str(full_test_dataset.data[i][1]) for i in range(len(full_test_dataset))]


train_indices, test_indices = train_test_split(range(len(full_test_dataset)),
                                               stratify=captions,
                                               test_size=0.2)  


train_dataset = full_test_dataset.subset(train_indices)
val_dataset = full_test_dataset.subset(test_indices)


train_data_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2, collate_fn=collate_fn)
val_data_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2, collate_fn=collate_fn)

# %% [markdown]
# # Model Building

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models.mobilenetv2 import MobileNet_V2_Weights
import torch.nn.functional as F

# %% [markdown]
# ## Attention

# %%
import math

class Attention(nn.Module):
    def __init__(self):
        super(Attention, self).__init__()

    def forward(self, query, key, value):
        # Compute the dot product between query and key
        scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(query.size(-1))
        attn_weights = F.softmax(scores, dim=-1)
        context = torch.matmul(attn_weights, value)
        return context, attn_weights

# %% [markdown]
# ## Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, hidden_size, num_layers=1, num_frames=80):
        super(Encoder, self).__init__()
        self.num_frames = num_frames

        # CNN Part to get the features of every frame
        mobilenet_weights = MobileNet_V2_Weights.DEFAULT
        mobilenet = models.mobilenet_v2(weights=mobilenet_weights)
        modules = list(mobilenet.children())[:-1]  # Remove the classifier layer to just take the features
        self.mobilenet = nn.Sequential(*modules)

        # Freeze the MobileNet weights
        for param in self.mobilenet.parameters():
            param.requires_grad = False

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # LSTM Part
        self.lstm = nn.LSTM(mobilenet.last_channel*8*8, hidden_size, num_layers, batch_first=True)


    def forward(self, images):
        # images shape: (batch_size, num_frames, C, H, W)
        batch_size, _, C, H, W = images.size()
        assert self.num_frames == images.size(1), "Each video should have 80 frames"

        cnn_in = images.view(batch_size * self.num_frames, C, H, W)

        # Pass each frame through the CNN
        features = self.mobilenet(cnn_in)
        #convert it from (1280, 8, 8) into (1280*8*8)
        features = features.view(batch_size, self.num_frames, -1)

        # Pass the sequence of features through the LSTM
        lstm_out, (hidden_states, cell_states) = self.lstm(features)

        # Retrieve the final hidden state for the last time step
        final_hidden_states = hidden_states[-1]
        final_cell_states = cell_states[-1]
        return lstm_out, final_hidden_states, final_cell_states

# %% [markdown]
# ## Decoder

# %%
import torch
import torch.nn as nn

class Decoder(nn.Module):
    def __init__(self, vocab, embed_size, hidden_size, vocab_size, dropout=0.5, max_seq_length=20):
        super(Decoder, self).__init__()
        self.vocab = vocab
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.num_layers = 1
        self.num_directions = 1

        self.lstm = nn.LSTMCell(input_size=embed_size, hidden_size=hidden_size)
        self.fc_out = nn.Linear(in_features=hidden_size * 2, out_features=vocab_size)
        self.embed = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embed_size)
        self.dropout = nn.Dropout(dropout)
        self.max_seq_length = max_seq_length
        self.attention = Attention()

    def forward(self, captions, encoder_outputs, hidden_state, cell_state, state = 'test'):
        batch_size = captions.size(0)
        hidden_state = hidden_state.view(batch_size, self.hidden_size)
        cell_state = cell_state.view(batch_size, self.hidden_size)

        max_forward_length = self.max_seq_length if state=='test' else captions.size(1)

        # Tensor to store decoder outputs
        outputs = torch.zeros(batch_size, max_forward_length, self.vocab_size).to(captions.device)

        input = captions[:, 0]

        for t in range(0, max_forward_length):
            captions_embed = self.embed(input)
            hidden_state, cell_state = self.lstm(captions_embed, (hidden_state, cell_state))

            # Apply attention
            context, _ = self.attention(hidden_state.unsqueeze(1), encoder_outputs, encoder_outputs)
            context = context.squeeze(1)

            # Combine context with LSTM output before final layer
            output = self.fc_out(self.dropout(torch.cat((hidden_state, context), dim=1)))
            outputs[:, t, :] = output

            if self.training:
                # Pass the correct output for training purposes
                input = captions[:, t+1] if t+1<captions.size(1) else None
            else:
                # Get the highest predicted word from the previous output for evaluation
                top1 = output.argmax(1)
                input = top1
        return outputs[:, :t, :]

# %% [markdown]
# ## Validation Function

# %%
def validate_model(encoder, decoder, val_data_loader, criterion):
    encoder.eval()
    decoder.eval()
    total_val_loss = 0
    with torch.no_grad():
        for frames, captions in val_data_loader:
            frames, captions = frames.to(device), captions.to(device)
            encoder_output, hidden_state, cell_state = encoder(frames)
            outputs = decoder(captions[:, :],encoder_output, hidden_state, cell_state, state = 'val')
            loss = criterion(outputs.reshape(-1, outputs.size(2)), captions[:, 1:].contiguous().view(-1))
            total_val_loss += loss.item()
    return total_val_loss / len(val_data_loader)

# %% [markdown]
# ## Train Loop

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train(encoder, decoder, encoder_filename, decoder_filename):
  encoder.to(device)
  decoder.to(device)

  # Define loss function and optimizers
  criterion = nn.CrossEntropyLoss(ignore_index=vocab['<pad>'])
  parameters = list(encoder.parameters()) + list(decoder.parameters())
  optimizer = optim.Adam(parameters, lr=0.0001)

  # Training loop
  num_epochs = 10  
  best_val_loss = float('inf')
  for epoch in range(num_epochs):
      encoder.train()
      decoder.train()
      total_loss = 0

      for batch_idx, (frames, captions) in enumerate(train_data_loader):
          frames, captions = frames.to(device), captions.to(device)

          # Zero the gradients
          optimizer.zero_grad()


          # Forward pass through the encoder
          encoder_output, hidden_state, cell_state = encoder(frames)

          # Forward pass through the decoder
          outputs = decoder(captions[:, :], encoder_output, hidden_state, cell_state, state = 'train')

          # Calculate the loss
          loss = criterion(outputs.reshape(-1, outputs.size(2)), captions[:, 1:].contiguous().view(-1))
          total_loss += loss.item()

          # Backward pass and optimize
          loss.backward()
          optimizer.step()


          if batch_idx % 10 == 0:  # Print loss every 10 batches
              print(f"Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_data_loader)}], Loss: {loss.item():.4f}")

      # Print epoch loss
      print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_data_loader):.4f}')

      # Validation phase
      val_loss = validate_model(encoder, decoder, val_data_loader, criterion)
      print(f'Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_loss:.4f}')

      # Check for early stopping
      if val_loss < best_val_loss:
          print(f'Saving Model! {val_loss} < {best_val_loss}')
          best_val_loss = val_loss

          torch.save(encoder.state_dict(), encoder_filename)
          torch.save(decoder.state_dict(), decoder_filename)

# %% [markdown]
# Version 1: hidden_size = 256

# %%
# Initialize models
encoder = Encoder(hidden_size=256)
decoder = Decoder(vocab = vocab, embed_size=256, hidden_size=256, vocab_size=len(vocab), dropout=0.2)

# Check if CUDA is available and move models to GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train(encoder, decoder, "encoder_v1.pth", "decoder_v1.pth")
# Out:
# Epoch [1/10], Step [1/107], Loss: 3.5177
# Epoch [1/10], Step [11/107], Loss: 2.5982
# Epoch [1/10], Step [21/107], Loss: 2.6639
# Epoch [1/10], Step [31/107], Loss: 2.5630
# Epoch [1/10], Step [41/107], Loss: 2.1911
# Epoch [1/10], Step [51/107], Loss: 2.1477
# Epoch [1/10], Step [61/107], Loss: 2.6897
# Epoch [1/10], Step [71/107], Loss: 3.0765
# Epoch [1/10], Step [81/107], Loss: 2.8686
# Epoch [1/10], Step [91/107], Loss: 1.9804
# Epoch [1/10], Step [101/107], Loss: 2.2476
# Epoch [1/10], Loss: 2.4816
# Epoch [1/10], Validation Loss: 2.4800
# Saving Model! 2.4799630374551933 < inf
# Epoch [2/10], Step [1/107], Loss: 1.5750
# Epoch [2/10], Step [11/107], Loss: 1.5585
# Epoch [2/10], Step [21/107], Loss: 2.1051
# Epoch [2/10], Step [31/107], Loss: 2.1921
# Epoch [2/10], Step [41/107], Loss: 2.0132
# Epoch [2/10], Step [51/107], Loss: 1.9613
# Epoch [2/10], Step [61/107], Loss: 1.6413
# Epoch [2/10], Step [71/107], Loss: 2.2427
# Epoch [2/10], Step [81/107], Loss: 2.2462
# Epoch [2/10], Step [91/107], Loss: 2.2049
# Epoch [2/10], Step [101/107], Loss: 1.5929
# Epoch [2/10], Loss: 1.8988
# Epoch [2/10], Validation Loss: 1.9931
# Saving Model! 1.9930922160638826 < 2.4799630374551933
# Epoch [3/10], Step [1/107], Loss: 1.5258
# Epoch [3/10], Step [11/107], Loss: 1.4717
# Epoch [3/10], Step [21/107], Loss: 1.3555
# Epoch [3/10], Step [31/107], Loss: 1.7404
# Epoch [3/10], Step [41/107], Loss: 1.4688
# Epoch [3/10], Step [51/107], Loss: 1.8774
# Epoch [3/10], Step [61/107], Loss: 1.9713
# Epoch [3/10], Step [71/107], Loss: 1.3363
# Epoch [3/10], Step [81/107], Loss: 1.5547
# Epoch [3/10], Step [91/107], Loss: 1.2496
# Epoch [3/10], Step [101/107], Loss: 1.0702
# Epoch [3/10], Loss: 1.4587
# Epoch [3/10], Validation Loss: 1.4746
# Saving Model! 1.474555828860987 < 1.9930922160638826
# Epoch [4/10], Step [1/107], Loss: 1.1024
# Epoch [4/10], Step [11/107], Loss: 0.9822
# Epoch [4/10], Step [21/107], Loss: 1.4233
# Epoch [4/10], Step [31/107], Loss: 0.7799
# Epoch [4/10], Step [41/107], Loss: 1.2795
# Epoch [4/10], Step [51/107], Loss: 1.0848
# Epoch [4/10], Step [61/107], Loss: 0.8644
# Epoch [4/10], Step [71/107], Loss: 1.1885
# Epoch [4/10], Step [81/107], Loss: 1.3851
# Epoch [4/10], Step [91/107], Loss: 0.6788
# Epoch [4/10], Step [101/107], Loss: 0.7558
# Epoch [4/10], Loss: 1.0512
# Epoch [4/10], Validation Loss: 1.0186
# Saving Model! 1.0185683659303968 < 1.474555828860987
# Epoch [5/10], Step [1/107], Loss: 0.7160
# Epoch [5/10], Step [11/107], Loss: 0.7045
# Epoch [5/10], Step [21/107], Loss: 0.8551
# Epoch [5/10], Step [31/107], Loss: 0.6765
# Epoch [5/10], Step [41/107], Loss: 0.7007
# Epoch [5/10], Step [51/107], Loss: 0.7399
# Epoch [5/10], Step [61/107], Loss: 0.7873
# Epoch [5/10], Step [71/107], Loss: 0.7701
# Epoch [5/10], Step [81/107], Loss: 0.5320
# Epoch [5/10], Step [91/107], Loss: 0.8199
# Epoch [5/10], Step [101/107], Loss: 0.4574
# Epoch [5/10], Loss: 0.6799
# Epoch [5/10], Validation Loss: 0.6542
# Saving Model! 0.6542176604270935 < 1.0185683659303968
# Epoch [6/10], Step [1/107], Loss: 0.5463
# Epoch [6/10], Step [11/107], Loss: 0.5682
# Epoch [6/10], Step [21/107], Loss: 0.4700
# Epoch [6/10], Step [31/107], Loss: 0.3408
# Epoch [6/10], Step [41/107], Loss: 0.2746
# Epoch [6/10], Step [51/107], Loss: 0.4628
# Epoch [6/10], Step [61/107], Loss: 0.3379
# Epoch [6/10], Step [71/107], Loss: 0.3472
# Epoch [6/10], Step [81/107], Loss: 0.3646
# Epoch [6/10], Step [91/107], Loss: 0.1768
# Epoch [6/10], Step [101/107], Loss: 0.2796
# Epoch [6/10], Loss: 0.3881
# Epoch [6/10], Validation Loss: 0.3800
# Saving Model! 0.3799627449746444 < 0.6542176604270935
# Epoch [7/10], Step [1/107], Loss: 0.2512
# Epoch [7/10], Step [11/107], Loss: 0.3468
# Epoch [7/10], Step [21/107], Loss: 0.1686
# Epoch [7/10], Step [31/107], Loss: 0.2619
# Epoch [7/10], Step [41/107], Loss: 0.2623
# Epoch [7/10], Step [51/107], Loss: 0.1818
# Epoch [7/10], Step [61/107], Loss: 0.2014
# Epoch [7/10], Step [71/107], Loss: 0.2437
# Epoch [7/10], Step [81/107], Loss: 0.2806
# Epoch [7/10], Step [91/107], Loss: 0.1939
# Epoch [7/10], Step [101/107], Loss: 0.2763
# Epoch [7/10], Loss: 0.2377
# Epoch [7/10], Validation Loss: 0.2485
# Saving Model! 0.24853734087164156 < 0.3799627449746444
# Epoch [8/10], Step [1/107], Loss: 0.1345
# Epoch [8/10], Step [11/107], Loss: 0.2061
# Epoch [8/10], Step [21/107], Loss: 0.1321
# Epoch [8/10], Step [31/107], Loss: 0.1743
# Epoch [8/10], Step [41/107], Loss: 0.1405
# Epoch [8/10], Step [51/107], Loss: 0.1993
# Epoch [8/10], Step [61/107], Loss: 0.1509
# Epoch [8/10], Step [71/107], Loss: 0.1715
# Epoch [8/10], Step [81/107], Loss: 0.2072
# Epoch [8/10], Step [91/107], Loss: 0.1606
# Epoch [8/10], Step [101/107], Loss: 0.1473
# Epoch [8/10], Loss: 0.1549
# Epoch [8/10], Validation Loss: 0.1799
# Saving Model! 0.17993364127996925 < 0.24853734087164156
# Epoch [9/10], Step [1/107], Loss: 0.1199
# Epoch [9/10], Step [11/107], Loss: 0.1327
# Epoch [9/10], Step [21/107], Loss: 0.0956
# Epoch [9/10], Step [31/107], Loss: 0.0971
# Epoch [9/10], Step [41/107], Loss: 0.1165
# Epoch [9/10], Step [51/107], Loss: 0.0782
# Epoch [9/10], Step [61/107], Loss: 0.0884
# Epoch [9/10], Step [71/107], Loss: 0.0868
# Epoch [9/10], Step [81/107], Loss: 0.1079
# Epoch [9/10], Step [91/107], Loss: 0.1153
# Epoch [9/10], Step [101/107], Loss: 0.0740
# Epoch [9/10], Loss: 0.1098
# Epoch [9/10], Validation Loss: 0.1445
# Saving Model! 0.14445340807471319 < 0.17993364127996925
# Epoch [10/10], Step [1/107], Loss: 0.1000
# Epoch [10/10], Step [11/107], Loss: 0.0963
# Epoch [10/10], Step [21/107], Loss: 0.0743
# Epoch [10/10], Step [31/107], Loss: 0.0937
# Epoch [10/10], Step [41/107], Loss: 0.0698
# Epoch [10/10], Step [51/107], Loss: 0.0746
# Epoch [10/10], Step [61/107], Loss: 0.0813
# Epoch [10/10], Step [71/107], Loss: 0.0909
# Epoch [10/10], Step [81/107], Loss: 0.0748
# Epoch [10/10], Step [91/107], Loss: 0.0732
# Epoch [10/10], Step [101/107], Loss: 0.0801
# Epoch [10/10], Loss: 0.0822
# Epoch [10/10], Validation Loss: 0.1058
# Saving Model! 0.1057876824079273 < 0.14445340807471319

# %% [markdown]
# Version 2: hidden_size = 512

# %%
# Initialize models
encoder = Encoder(hidden_size=512)
decoder = Decoder(vocab = vocab, embed_size=256, hidden_size=512, vocab_size=len(vocab), dropout=0.2)

# Check if CUDA is available and move models to GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train(encoder, decoder, "encoder_v2.pth", "decoder_v2.pth")
# Out:
# Epoch [1/10], Step [1/107], Loss: 3.4986
# Epoch [1/10], Step [11/107], Loss: 2.6621
# Epoch [1/10], Step [21/107], Loss: 2.5829
# Epoch [1/10], Step [31/107], Loss: 1.9167
# Epoch [1/10], Step [41/107], Loss: 2.6469
# Epoch [1/10], Step [51/107], Loss: 2.4583
# Epoch [1/10], Step [61/107], Loss: 2.2745
# Epoch [1/10], Step [71/107], Loss: 1.7546
# Epoch [1/10], Step [81/107], Loss: 1.7199
# Epoch [1/10], Step [91/107], Loss: 1.7483
# Epoch [1/10], Step [101/107], Loss: 1.8920
# Epoch [1/10], Loss: 2.2728
# Epoch [1/10], Validation Loss: 2.1358
# Saving Model! 2.1358425695205403 < inf
# Epoch [2/10], Step [1/107], Loss: 1.4494
# Epoch [2/10], Step [11/107], Loss: 1.9173
# Epoch [2/10], Step [21/107], Loss: 1.3251
# Epoch [2/10], Step [31/107], Loss: 1.4270
# Epoch [2/10], Step [41/107], Loss: 1.8062
# Epoch [2/10], Step [51/107], Loss: 1.1685
# Epoch [2/10], Step [61/107], Loss: 1.6185
# Epoch [2/10], Step [71/107], Loss: 1.2748
# Epoch [2/10], Step [81/107], Loss: 1.1987
# Epoch [2/10], Step [91/107], Loss: 1.7111
# Epoch [2/10], Step [101/107], Loss: 1.0838
# Epoch [2/10], Loss: 1.4722
# Epoch [2/10], Validation Loss: 1.2944
# Saving Model! 1.2943592383482745 < 2.1358425695205403
# Epoch [3/10], Step [1/107], Loss: 0.8690
# Epoch [3/10], Step [11/107], Loss: 1.0409
# Epoch [3/10], Step [21/107], Loss: 1.3420
# Epoch [3/10], Step [31/107], Loss: 1.1385
# Epoch [3/10], Step [41/107], Loss: 1.1796
# Epoch [3/10], Step [51/107], Loss: 0.9138
# Epoch [3/10], Step [61/107], Loss: 0.5750
# Epoch [3/10], Step [71/107], Loss: 0.6578
# Epoch [3/10], Step [81/107], Loss: 0.7415
# Epoch [3/10], Step [91/107], Loss: 0.5346
# Epoch [3/10], Step [101/107], Loss: 0.6079
# Epoch [3/10], Loss: 0.8118
# Epoch [3/10], Validation Loss: 0.6557
# Saving Model! 0.6556897756652297 < 1.2943592383482745
# Epoch [4/10], Step [1/107], Loss: 0.4709
# Epoch [4/10], Step [11/107], Loss: 0.3132
# Epoch [4/10], Step [21/107], Loss: 0.4306
# Epoch [4/10], Step [31/107], Loss: 0.3186
# Epoch [4/10], Step [41/107], Loss: 0.2768
# Epoch [4/10], Step [51/107], Loss: 0.6548
# Epoch [4/10], Step [61/107], Loss: 0.2505
# Epoch [4/10], Step [71/107], Loss: 0.2482
# Epoch [4/10], Step [81/107], Loss: 0.2696
# Epoch [4/10], Step [91/107], Loss: 0.2290
# Epoch [4/10], Step [101/107], Loss: 0.2737
# Epoch [4/10], Loss: 0.3534
# Epoch [4/10], Validation Loss: 0.3046
# Saving Model! 0.3046242566866295 < 0.6556897756652297
# Epoch [5/10], Step [1/107], Loss: 0.2689
# Epoch [5/10], Step [11/107], Loss: 0.2515
# Epoch [5/10], Step [21/107], Loss: 0.1891
# Epoch [5/10], Step [31/107], Loss: 0.1872
# Epoch [5/10], Step [41/107], Loss: 0.3299
# Epoch [5/10], Step [51/107], Loss: 0.1647
# Epoch [5/10], Step [61/107], Loss: 0.1633
# Epoch [5/10], Step [71/107], Loss: 0.1324
# Epoch [5/10], Step [81/107], Loss: 0.1262
# Epoch [5/10], Step [91/107], Loss: 0.1315
# Epoch [5/10], Step [101/107], Loss: 0.1154
# Epoch [5/10], Loss: 0.1656
# Epoch [5/10], Validation Loss: 0.1745
# Saving Model! 0.17452290354766578 < 0.3046242566866295
# Epoch [6/10], Step [1/107], Loss: 0.1214
# Epoch [6/10], Step [11/107], Loss: 0.1154
# Epoch [6/10], Step [21/107], Loss: 0.0974
# Epoch [6/10], Step [31/107], Loss: 0.0747
# Epoch [6/10], Step [41/107], Loss: 0.0773
# Epoch [6/10], Step [51/107], Loss: 0.0885
# Epoch [6/10], Step [61/107], Loss: 0.0996
# Epoch [6/10], Step [71/107], Loss: 0.1027
# Epoch [6/10], Step [81/107], Loss: 0.1152
# Epoch [6/10], Step [91/107], Loss: 0.0840
# Epoch [6/10], Step [101/107], Loss: 0.0707
# Epoch [6/10], Loss: 0.0868
# Epoch [6/10], Validation Loss: 0.1096
# Saving Model! 0.10956168916320132 < 0.17452290354766578
# Epoch [7/10], Step [1/107], Loss: 0.0509
# Epoch [7/10], Step [11/107], Loss: 0.0942
# Epoch [7/10], Step [21/107], Loss: 0.0619
# Epoch [7/10], Step [31/107], Loss: 0.0577
# Epoch [7/10], Step [41/107], Loss: 0.0814
# Epoch [7/10], Step [51/107], Loss: 0.0630
# Epoch [7/10], Step [61/107], Loss: 0.0426
# Epoch [7/10], Step [71/107], Loss: 0.0959
# Epoch [7/10], Step [81/107], Loss: 0.0475
# Epoch [7/10], Step [91/107], Loss: 0.0589
# Epoch [7/10], Step [101/107], Loss: 0.0695
# Epoch [7/10], Loss: 0.0570
# Epoch [7/10], Validation Loss: 0.0791
# Saving Model! 0.07913754953541488 < 0.10956168916320132
# Epoch [8/10], Step [1/107], Loss: 0.0390
# Epoch [8/10], Step [11/107], Loss: 0.0456
# Epoch [8/10], Step [21/107], Loss: 0.0366
# Epoch [8/10], Step [31/107], Loss: 0.0475
# Epoch [8/10], Step [41/107], Loss: 0.0321
# Epoch [8/10], Step [51/107], Loss: 0.0320
# Epoch [8/10], Step [61/107], Loss: 0.0337
# Epoch [8/10], Step [71/107], Loss: 0.0343
# Epoch [8/10], Step [81/107], Loss: 0.0306
# Epoch [8/10], Step [91/107], Loss: 0.0282
# Epoch [8/10], Step [101/107], Loss: 0.0350
# Epoch [8/10], Loss: 0.0375
# Epoch [8/10], Validation Loss: 0.0642
# Saving Model! 0.06418505415459659 < 0.07913754953541488
# Epoch [9/10], Step [1/107], Loss: 0.0275
# Epoch [9/10], Step [11/107], Loss: 0.0333
# Epoch [9/10], Step [21/107], Loss: 0.0269
# Epoch [9/10], Step [31/107], Loss: 0.0271
# Epoch [9/10], Step [41/107], Loss: 0.0181
# Epoch [9/10], Step [51/107], Loss: 0.0257
# Epoch [9/10], Step [61/107], Loss: 0.0212
# Epoch [9/10], Step [71/107], Loss: 0.0248
# Epoch [9/10], Step [81/107], Loss: 0.0263
# Epoch [9/10], Step [91/107], Loss: 0.0212
# Epoch [9/10], Step [101/107], Loss: 0.0276
# Epoch [9/10], Loss: 0.0272
# Epoch [9/10], Validation Loss: 0.0506
# Saving Model! 0.05061638846157867 < 0.06418505415459659
# Epoch [10/10], Step [1/107], Loss: 0.0250
# Epoch [10/10], Step [11/107], Loss: 0.0225
# Epoch [10/10], Step [21/107], Loss: 0.0319
# Epoch [10/10], Step [31/107], Loss: 0.0207
# Epoch [10/10], Step [41/107], Loss: 0.0197
# Epoch [10/10], Step [51/107], Loss: 0.0192
# Epoch [10/10], Step [61/107], Loss: 0.0182
# Epoch [10/10], Step [71/107], Loss: 0.0212
# Epoch [10/10], Step [81/107], Loss: 0.0219
# Epoch [10/10], Step [91/107], Loss: 0.0183
# Epoch [10/10], Step [101/107], Loss: 0.0154
# Epoch [10/10], Loss: 0.0214
# Epoch [10/10], Validation Loss: 0.0428
# Saving Model! 0.04281729033269058 < 0.05061638846157867

# %% [markdown]
# Version 3: hidden_size = 1024

# %%
# Initialize models
encoder = Encoder(hidden_size=1024)
decoder = Decoder(vocab = vocab, embed_size=256, hidden_size=1024, vocab_size=len(vocab), dropout=0.2)

# Check if CUDA is available and move models to GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train(encoder, decoder, "encoder_v3.pth", "decoder_v3.pth")
# Out:
# Epoch [1/10], Step [1/107], Loss: 3.5390
# Epoch [1/10], Step [11/107], Loss: 2.0261
# Epoch [1/10], Step [21/107], Loss: 2.0792
# Epoch [1/10], Step [31/107], Loss: 2.0749
# Epoch [1/10], Step [41/107], Loss: 1.8912
# Epoch [1/10], Step [51/107], Loss: 1.9288
# Epoch [1/10], Step [61/107], Loss: 2.6319
# Epoch [1/10], Step [71/107], Loss: 1.6559
# Epoch [1/10], Step [81/107], Loss: 1.8259
# Epoch [1/10], Step [91/107], Loss: 1.3396
# Epoch [1/10], Step [101/107], Loss: 1.0012
# Epoch [1/10], Loss: 2.1245
# Epoch [1/10], Validation Loss: 1.7460
# Saving Model! 1.746014816181682 < inf
# Epoch [2/10], Step [1/107], Loss: 1.3160
# Epoch [2/10], Step [11/107], Loss: 1.4942
# Epoch [2/10], Step [21/107], Loss: 0.9742
# Epoch [2/10], Step [31/107], Loss: 1.4279
# Epoch [2/10], Step [41/107], Loss: 0.7168
# Epoch [2/10], Step [51/107], Loss: 1.2136
# Epoch [2/10], Step [61/107], Loss: 1.3586
# Epoch [2/10], Step [71/107], Loss: 0.7061
# Epoch [2/10], Step [81/107], Loss: 0.9100
# Epoch [2/10], Step [91/107], Loss: 0.9165
# Epoch [2/10], Step [101/107], Loss: 0.9778
# Epoch [2/10], Loss: 1.0024
# Epoch [2/10], Validation Loss: 0.6838
# Saving Model! 0.6837773548665448 < 1.746014816181682
# Epoch [3/10], Step [1/107], Loss: 0.4840
# Epoch [3/10], Step [11/107], Loss: 0.3849
# Epoch [3/10], Step [21/107], Loss: 0.3837
# Epoch [3/10], Step [31/107], Loss: 0.4819
# Epoch [3/10], Step [41/107], Loss: 0.8360
# Epoch [3/10], Step [51/107], Loss: 0.2392
# Epoch [3/10], Step [61/107], Loss: 0.2762
# Epoch [3/10], Step [71/107], Loss: 0.2599
# Epoch [3/10], Step [81/107], Loss: 0.2203
# Epoch [3/10], Step [91/107], Loss: 0.2770
# Epoch [3/10], Step [101/107], Loss: 0.1509
# Epoch [3/10], Loss: 0.3322
# Epoch [3/10], Validation Loss: 0.2342
# Saving Model! 0.2341585159998074 < 0.6837773548665448
# Epoch [4/10], Step [1/107], Loss: 0.1124
# Epoch [4/10], Step [11/107], Loss: 0.1654
# Epoch [4/10], Step [21/107], Loss: 0.1468
# Epoch [4/10], Step [31/107], Loss: 0.1667
# Epoch [4/10], Step [41/107], Loss: 0.1332
# Epoch [4/10], Step [51/107], Loss: 0.1091
# Epoch [4/10], Step [61/107], Loss: 0.1341
# Epoch [4/10], Step [71/107], Loss: 0.1180
# Epoch [4/10], Step [81/107], Loss: 0.0666
# Epoch [4/10], Step [91/107], Loss: 0.0574
# Epoch [4/10], Step [101/107], Loss: 0.0950
# Epoch [4/10], Loss: 0.1095
# Epoch [4/10], Validation Loss: 0.1151
# Saving Model! 0.11510374463189428 < 0.2341585159998074
# Epoch [5/10], Step [1/107], Loss: 0.2292
# Epoch [5/10], Step [11/107], Loss: 0.0992
# Epoch [5/10], Step [21/107], Loss: 0.0721
# Epoch [5/10], Step [31/107], Loss: 0.0570
# Epoch [5/10], Step [41/107], Loss: 0.0511
# Epoch [5/10], Step [51/107], Loss: 0.0444
# Epoch [5/10], Step [61/107], Loss: 0.0376
# Epoch [5/10], Step [71/107], Loss: 0.0551
# Epoch [5/10], Step [81/107], Loss: 0.0301
# Epoch [5/10], Step [91/107], Loss: 0.0507
# Epoch [5/10], Step [101/107], Loss: 0.0237
# Epoch [5/10], Loss: 0.0526
# Epoch [5/10], Validation Loss: 0.0642
# Saving Model! 0.06420200401655982 < 0.11510374463189428
# Epoch [6/10], Step [1/107], Loss: 0.0291
# Epoch [6/10], Step [11/107], Loss: 0.0308
# Epoch [6/10], Step [21/107], Loss: 0.0321
# Epoch [6/10], Step [31/107], Loss: 0.0215
# Epoch [6/10], Step [41/107], Loss: 0.0190
# Epoch [6/10], Step [51/107], Loss: 0.0237
# Epoch [6/10], Step [61/107], Loss: 0.0258
# Epoch [6/10], Step [71/107], Loss: 0.0326
# Epoch [6/10], Step [81/107], Loss: 0.0296
# Epoch [6/10], Step [91/107], Loss: 0.0212
# Epoch [6/10], Step [101/107], Loss: 0.0275
# Epoch [6/10], Loss: 0.0260
# Epoch [6/10], Validation Loss: 0.0416
# Saving Model! 0.04162660408242841 < 0.06420200401655982
# Epoch [7/10], Step [1/107], Loss: 0.0186
# Epoch [7/10], Step [11/107], Loss: 0.0197
# Epoch [7/10], Step [21/107], Loss: 0.0212
# Epoch [7/10], Step [31/107], Loss: 0.0126
# Epoch [7/10], Step [41/107], Loss: 0.0134
# Epoch [7/10], Step [51/107], Loss: 0.0141
# Epoch [7/10], Step [61/107], Loss: 0.0173
# Epoch [7/10], Step [71/107], Loss: 0.0200
# Epoch [7/10], Step [81/107], Loss: 0.0135
# Epoch [7/10], Step [91/107], Loss: 0.0132
# Epoch [7/10], Step [101/107], Loss: 0.0122
# Epoch [7/10], Loss: 0.0165
# Epoch [7/10], Validation Loss: 0.0388
# Saving Model! 0.03878197562228018 < 0.04162660408242841
# Epoch [8/10], Step [1/107], Loss: 0.0116
# Epoch [8/10], Step [11/107], Loss: 0.0185
# Epoch [8/10], Step [21/107], Loss: 0.0120
# Epoch [8/10], Step [31/107], Loss: 0.0131
# Epoch [8/10], Step [41/107], Loss: 0.0149
# Epoch [8/10], Step [51/107], Loss: 0.0105
# Epoch [8/10], Step [61/107], Loss: 0.0158
# Epoch [8/10], Step [71/107], Loss: 0.0090
# Epoch [8/10], Step [81/107], Loss: 0.0099
# Epoch [8/10], Step [91/107], Loss: 0.0101
# Epoch [8/10], Step [101/107], Loss: 0.0096
# Epoch [8/10], Loss: 0.0119
# Epoch [8/10], Validation Loss: 0.0320
# Saving Model! 0.0320235289476603 < 0.03878197562228018
# Epoch [9/10], Step [1/107], Loss: 0.0098
# Epoch [9/10], Step [11/107], Loss: 0.0146
# Epoch [9/10], Step [21/107], Loss: 0.0098
# Epoch [9/10], Step [31/107], Loss: 0.0099
# Epoch [9/10], Step [41/107], Loss: 0.0085
# Epoch [9/10], Step [51/107], Loss: 0.0087
# Epoch [9/10], Step [61/107], Loss: 0.0086
# Epoch [9/10], Step [71/107], Loss: 0.0079
# Epoch [9/10], Step [81/107], Loss: 0.0096
# Epoch [9/10], Step [91/107], Loss: 0.0093
# Epoch [9/10], Step [101/107], Loss: 0.0085
# Epoch [9/10], Loss: 0.0092
# Epoch [9/10], Validation Loss: 0.0282
# Saving Model! 0.028186760464178347 < 0.0320235289476603
# Epoch [10/10], Step [1/107], Loss: 0.0088
# Epoch [10/10], Step [11/107], Loss: 0.0053
# Epoch [10/10], Step [21/107], Loss: 0.0065
# Epoch [10/10], Step [31/107], Loss: 0.0057
# Epoch [10/10], Step [41/107], Loss: 0.0063
# Epoch [10/10], Step [51/107], Loss: 0.0063
# Epoch [10/10], Step [61/107], Loss: 0.0057
# Epoch [10/10], Step [71/107], Loss: 0.0044
# Epoch [10/10], Step [81/107], Loss: 0.0079
# Epoch [10/10], Step [91/107], Loss: 0.0075
# Epoch [10/10], Step [101/107], Loss: 0.0072
# Epoch [10/10], Loss: 0.0071
# Epoch [10/10], Validation Loss: 0.0267
# Saving Model! 0.02671226718959129 < 0.028186760464178347

# %% [markdown]
# Therefore, Version 3 is the best one, with 1024 hidden size.

# %%
# Initialize models
encoder = Encoder(hidden_size=1024)
decoder = Decoder(vocab = vocab, embed_size=256, hidden_size=1024, vocab_size=len(vocab), dropout=0.2)

# Check if CUDA is available and move models to GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train(encoder, decoder, "encoder_v3.pth", "decoder_v3.pth")
# Out:
# Epoch [1/10], Step [1/107], Loss: 3.5185
# Epoch [1/10], Step [11/107], Loss: 2.4386
# Epoch [1/10], Step [21/107], Loss: 2.2330
# Epoch [1/10], Step [31/107], Loss: 2.5829
# Epoch [1/10], Step [41/107], Loss: 2.0005
# Epoch [1/10], Step [51/107], Loss: 1.4852
# Epoch [1/10], Step [61/107], Loss: 1.9690
# Epoch [1/10], Step [71/107], Loss: 1.6024
# Epoch [1/10], Step [81/107], Loss: 1.5708
# Epoch [1/10], Step [91/107], Loss: 2.3873
# Epoch [1/10], Step [101/107], Loss: 1.5814
# Epoch [1/10], Loss: 2.0646
# Epoch [1/10], Validation Loss: 1.6553
# Saving Model! 1.655275051281831 < inf
# Epoch [2/10], Step [1/107], Loss: 1.5466
# Epoch [2/10], Step [11/107], Loss: 1.0578
# Epoch [2/10], Step [21/107], Loss: 1.3068
# Epoch [2/10], Step [31/107], Loss: 0.9122
# Epoch [2/10], Step [41/107], Loss: 0.8101
# Epoch [2/10], Step [51/107], Loss: 0.5381
# Epoch [2/10], Step [61/107], Loss: 1.4579
# Epoch [2/10], Step [71/107], Loss: 0.7305
# Epoch [2/10], Step [81/107], Loss: 0.7090
# Epoch [2/10], Step [91/107], Loss: 0.8425
# Epoch [2/10], Step [101/107], Loss: 0.5708
# Epoch [2/10], Loss: 0.9726
# Epoch [2/10], Validation Loss: 0.8243
# Saving Model! 0.824280769468468 < 1.655275051281831
# Epoch [3/10], Step [1/107], Loss: 0.7337
# Epoch [3/10], Step [11/107], Loss: 1.2151
# Epoch [3/10], Step [21/107], Loss: 0.3794
# Epoch [3/10], Step [31/107], Loss: 0.2717
# Epoch [3/10], Step [41/107], Loss: 0.2782
# Epoch [3/10], Step [51/107], Loss: 0.3341
# Epoch [3/10], Step [61/107], Loss: 0.3057
# Epoch [3/10], Step [71/107], Loss: 0.2122
# Epoch [3/10], Step [81/107], Loss: 0.2569
# Epoch [3/10], Step [91/107], Loss: 0.2048
# Epoch [3/10], Step [101/107], Loss: 0.2645
# Epoch [3/10], Loss: 0.3621
# Epoch [3/10], Validation Loss: 0.2602
# Saving Model! 0.26022663573238336 < 0.824280769468468
# Epoch [4/10], Step [1/107], Loss: 0.1232
# Epoch [4/10], Step [11/107], Loss: 0.1303
# Epoch [4/10], Step [21/107], Loss: 0.2080
# Epoch [4/10], Step [31/107], Loss: 0.1345
# Epoch [4/10], Step [41/107], Loss: 0.0829
# Epoch [4/10], Step [51/107], Loss: 0.0800
# Epoch [4/10], Step [61/107], Loss: 0.0971
# Epoch [4/10], Step [71/107], Loss: 0.0786
# Epoch [4/10], Step [81/107], Loss: 0.0709
# Epoch [4/10], Step [91/107], Loss: 0.0549
# Epoch [4/10], Step [101/107], Loss: 0.0671
# Epoch [4/10], Loss: 0.1207
# Epoch [4/10], Validation Loss: 0.1213
# Saving Model! 0.12129798047592706 < 0.26022663573238336
# Epoch [5/10], Step [1/107], Loss: 0.0548
# Epoch [5/10], Step [11/107], Loss: 0.0724
# Epoch [5/10], Step [21/107], Loss: 0.0689
# Epoch [5/10], Step [31/107], Loss: 0.0593
# Epoch [5/10], Step [41/107], Loss: 0.0452
# Epoch [5/10], Step [51/107], Loss: 0.0424
# Epoch [5/10], Step [61/107], Loss: 0.0507
# Epoch [5/10], Step [71/107], Loss: 0.0525
# Epoch [5/10], Step [81/107], Loss: 0.0432
# Epoch [5/10], Step [91/107], Loss: 0.0360
# Epoch [5/10], Step [101/107], Loss: 0.0466
# Epoch [5/10], Loss: 0.0476
# Epoch [5/10], Validation Loss: 0.0731
# Saving Model! 0.0731030250333737 < 0.12129798047592706
# Epoch [6/10], Step [1/107], Loss: 0.0485
# Epoch [6/10], Step [11/107], Loss: 0.0238
# Epoch [6/10], Step [21/107], Loss: 0.0270
# Epoch [6/10], Step [31/107], Loss: 0.0224
# Epoch [6/10], Step [41/107], Loss: 0.0282
# Epoch [6/10], Step [51/107], Loss: 0.0246
# Epoch [6/10], Step [61/107], Loss: 0.0234
# Epoch [6/10], Step [71/107], Loss: 0.0252
# Epoch [6/10], Step [81/107], Loss: 0.0264
# Epoch [6/10], Step [91/107], Loss: 0.0243
# Epoch [6/10], Step [101/107], Loss: 0.0229
# Epoch [6/10], Loss: 0.0269
# Epoch [6/10], Validation Loss: 0.0487
# Saving Model! 0.04869550355126925 < 0.0731030250333737
# Epoch [7/10], Step [1/107], Loss: 0.0151
# Epoch [7/10], Step [11/107], Loss: 0.0183
# Epoch [7/10], Step [21/107], Loss: 0.0200
# Epoch [7/10], Step [31/107], Loss: 0.0183
# Epoch [7/10], Step [41/107], Loss: 0.0166
# Epoch [7/10], Step [51/107], Loss: 0.0148
# Epoch [7/10], Step [61/107], Loss: 0.0210
# Epoch [7/10], Step [71/107], Loss: 0.0166
# Epoch [7/10], Step [81/107], Loss: 0.0161
# Epoch [7/10], Step [91/107], Loss: 0.0134
# Epoch [7/10], Step [101/107], Loss: 0.0111
# Epoch [7/10], Loss: 0.0172
# Epoch [7/10], Validation Loss: 0.0423
# Saving Model! 0.04232567331153099 < 0.04869550355126925
# Epoch [8/10], Step [1/107], Loss: 0.0147
# Epoch [8/10], Step [11/107], Loss: 0.0132
# Epoch [8/10], Step [21/107], Loss: 0.0138
# Epoch [8/10], Step [31/107], Loss: 0.0144
# Epoch [8/10], Step [41/107], Loss: 0.0116
# Epoch [8/10], Step [51/107], Loss: 0.0159
# Epoch [8/10], Step [61/107], Loss: 0.0129
# Epoch [8/10], Step [71/107], Loss: 0.0106
# Epoch [8/10], Step [81/107], Loss: 0.0120
# Epoch [8/10], Step [91/107], Loss: 0.0119
# Epoch [8/10], Step [101/107], Loss: 0.0109
# Epoch [8/10], Loss: 0.0124
# Epoch [8/10], Validation Loss: 0.0378
# Saving Model! 0.03780741731105285 < 0.04232567331153099
# Epoch [9/10], Step [1/107], Loss: 0.0122
# Epoch [9/10], Step [11/107], Loss: 0.0073
# Epoch [9/10], Step [21/107], Loss: 0.0109
# Epoch [9/10], Step [31/107], Loss: 0.0099
# Epoch [9/10], Step [41/107], Loss: 0.0191
# Epoch [9/10], Step [51/107], Loss: 0.0082
# Epoch [9/10], Step [61/107], Loss: 0.0089
# Epoch [9/10], Step [71/107], Loss: 0.0081
# Epoch [9/10], Step [81/107], Loss: 0.0083
# Epoch [9/10], Step [91/107], Loss: 0.0092
# Epoch [9/10], Step [101/107], Loss: 0.0125
# Epoch [9/10], Loss: 0.0093
# Epoch [9/10], Validation Loss: 0.0318
# Saving Model! 0.031779662018345894 < 0.03780741731105285
# Epoch [10/10], Step [1/107], Loss: 0.0110
# Epoch [10/10], Step [11/107], Loss: 0.0097
# Epoch [10/10], Step [21/107], Loss: 0.0067
# Epoch [10/10], Step [31/107], Loss: 0.0095
# Epoch [10/10], Step [41/107], Loss: 0.0077
# Epoch [10/10], Step [51/107], Loss: 0.0065
# Epoch [10/10], Step [61/107], Loss: 0.0080
# Epoch [10/10], Step [71/107], Loss: 0.0078
# Epoch [10/10], Step [81/107], Loss: 0.0070
# Epoch [10/10], Step [91/107], Loss: 0.0085
# Epoch [10/10], Step [101/107], Loss: 0.0060
# Epoch [10/10], Loss: 0.0072
# Epoch [10/10], Validation Loss: 0.0283
# Saving Model! 0.028295024668049312 < 0.031779662018345894

# %% [markdown]
# # Testing on testing set

# %%
encoder = Encoder(hidden_size=1024).to(device)
decoder = Decoder(vocab = vocab, embed_size=256, hidden_size=1024, vocab_size=len(vocab), dropout=0.2).to(device)

encoder.load_state_dict(torch.load('encoder_v3.pth'))
decoder.load_state_dict(torch.load('decoder_v3.pth'))

encoder.eval()
decoder.eval()
# Out:
# Decoder(
#   (vocab): Vocab()
#   (lstm): LSTMCell(256, 1024)
#   (fc_out): Linear(in_features=2048, out_features=34, bias=True)
#   (embed): Embedding(34, 256)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (attention): Attention()
# )

# %%
def generate_caption(decoder, vocab, encoder_outputs, hidden_state, cell_state, device, max_length=20):
    start_token_idx = vocab.lookup_indices(['<sos>'])[0]  # Fetch the index for <sos>
    sequence = torch.tensor([[start_token_idx]], dtype=torch.long).to(device)

    with torch.no_grad():
        outputs = decoder(sequence, encoder_outputs, hidden_state, cell_state, state='test')

    predicted_indices = outputs.squeeze(0).argmax(dim=1).tolist()
    caption = indices_to_string(predicted_indices, vocab)

    return caption



def indices_to_string(indices, vocab):
    if isinstance(indices, torch.Tensor):
        indices = indices.tolist()

    words = [vocab.get_itos()[idx] for idx in indices]

    # Exclude special tokens like <start>, <end>, and <pad> from the final sentence
    special_tokens = {'<sos>', '<eos>', '<pad>'}
    filtered_words = [word for word in words if word not in special_tokens]

    # Join the words to form a sentence
    sentence = ' '.join(filtered_words)

    return sentence

# %% [markdown]
# ## Testing set results

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.5.2

# %%
import jiwer

def calculate_wer(reference, hypothesis):
    return jiwer.wer(reference, hypothesis)

total_wer = 0
num_samples = 0

for frames, captions in test_data_loader:
    frames = frames.to(device)
    captions = captions.to(device)

    with torch.no_grad():
        encoder_output, hidden_states, cell_states = encoder(frames)

    hidden = hidden_states[0].unsqueeze(0)
    cell = cell_states[0].unsqueeze(0)

    true_caption_indices = captions[0]
    generated_caption = generate_caption(decoder, vocab, encoder_output, hidden, cell, device)

    # Convert true caption indices to string
    true_caption = indices_to_string(true_caption_indices, vocab)

    # Calculate and accumulate WER
    wer = calculate_wer(true_caption, generated_caption)
    total_wer += wer
    num_samples += 1

    print(f"True Caption: {true_caption}")
    print(f"Generated Caption: {generated_caption}")
    print(f"WER: {wer}\n")

# Calculate average WER across the test set
average_wer = total_wer / num_samples
print(f"Average WER on the Test Set: {average_wer}")
# Out:
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# True Caption: الله اكبر
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: اليوم اقدم انتم برنامج
# WER: 1.3333333333333333
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: الحمد الله
# WER: 0.8
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: كلمات اليوم متفرقة في
# WER: 2.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: الله اكبر
# Generated Caption: لا شرك الله
# WER: 1.5
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: الحمد الله
# WER: 0.8
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.25
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: اليوم اقدم انتم برنامج
# WER: 1.3333333333333333
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 1.25
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: اليوم اقدم انتم برنامج
# WER: 1.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 2.0
#
# True Caption: الحمد الله
# Generated Caption: كلمات اليوم متفرقة في
# WER: 2.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: الله اكبر
# Generated Caption: لا شرك الله
# WER: 1.5
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 1.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 1.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: لا شرك الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.25
#
# True Caption: اسم الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# True Caption: الحمد الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة
# WER: 0.2
#
# True Caption: الله اكبر
# Generated Caption: لا شرك الله
# WER: 1.5
#
# True Caption: الله اكبر
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.25
#
# True Caption: الحمد الله
# Generated Caption: كلمات اليوم متفرقة في
# WER: 2.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 1.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 1.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 1.25
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 1.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 1.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 1.6666666666666667
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 1.0
#
# True Caption: اسم الله
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 2.5
#
# Average WER on the Test Set: 0.9325757575757574

# %% [markdown]
# ### Average WER on the Test Set: 0.9325757575757574
# The reasoning behind this is that it could be due to the heavy difference between the train and test datasets. We noticed that the validation loss was actually very good, but all of a sudden the test has a very bad accuracy.

# %% [markdown]
# ## Validation set results

# %%
total_wer = 0
num_samples = 0
# Test data loader
evaluation_train_data_loader = get_data_loader(
    root_dir='/content/Assignment03/train/',
    caption_mapping=caption_mapping,
    vocab=vocab,
    batch_size=1,
    transform=train_transform,
    shuffle=True,
    num_workers=2
)
for frames, captions in val_data_loader:
    frames = frames.to(device)
    captions = captions.to(device)

    with torch.no_grad():
        encoder_output, hidden_states, cell_states = encoder(frames)

    hidden = hidden_states[0].unsqueeze(0)
    cell = cell_states[0].unsqueeze(0)

    true_caption_indices = captions[0]
    generated_caption = generate_caption(decoder, vocab, encoder_output, hidden, cell, device)

    # Convert true caption indices to string
    true_caption = indices_to_string(true_caption_indices, vocab)

    # Calculate and accumulate WER
    wer = calculate_wer(true_caption, generated_caption)
    total_wer += wer
    num_samples += 1

    print(f"True Caption: {true_caption}")
    print(f"Generated Caption: {generated_caption}")
    print(f"WER: {wer}\n")

# Calculate average WER across the test set
average_wer = total_wer / num_samples
print(f"Average WER on the Validation Set: {average_wer}")
# Out:
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# Average WER on the Validation Set: 0.009345794392523364

# %% [markdown]
# ### Average WER on the Validation Set: 0.009345794392523364

# %% [markdown]
# ## Training set results

# %%
total_wer = 0
num_samples = 0
# Test data loader
evaluation_train_data_loader = get_data_loader(
    root_dir='/content/Assignment03/train/',
    caption_mapping=caption_mapping,
    vocab=vocab,
    batch_size=1,
    transform=train_transform,
    shuffle=True,
    num_workers=2
)
for frames, captions in evaluation_train_data_loader:
    frames = frames.to(device)
    captions = captions.to(device)

    with torch.no_grad():
        encoder_output, hidden_states, cell_states = encoder(frames)

    hidden = hidden_states[0].unsqueeze(0)
    cell = cell_states[0].unsqueeze(0)

    true_caption_indices = captions[0]
    generated_caption = generate_caption(decoder, vocab, encoder_output, hidden, cell, device)

    # Convert true caption indices to string
    true_caption = indices_to_string(true_caption_indices, vocab)

    # Calculate and accumulate WER
    wer = calculate_wer(true_caption, generated_caption)
    total_wer += wer
    num_samples += 1

    print(f"True Caption: {true_caption}")
    print(f"Generated Caption: {generated_caption}")
    print(f"WER: {wer}\n")

# Calculate average WER across the test set
average_wer = total_wer / num_samples
print(f"Average WER on the Train Set: {average_wer}")
# Out:
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: الحمد الله
# WER: 0.5
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: جميع الصم العرب السامع
# Generated Caption: جميع الصم العرب السامع
# WER: 0.0
#
# True Caption: اليوم اقدم انتم برنامج اخر
# Generated Caption: اليوم اقدم انتم برنامج اخر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: كلمات اليوم متفرقة في الدين
# Generated Caption: كلمات اليوم متفرقة في الدين
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: موضوع دراسة لغة الاشارة العربية
# Generated Caption: موضوع دراسة لغة الاشارة العربية
# WER: 0.0
#
# True Caption: اسم الله
# Generated Caption: اسم الله
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الحمد الله
# Generated Caption: الحمد الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: ايضا كلمات عادية
# Generated Caption: ايضا كلمات عادية
# WER: 0.0
#
# True Caption: لا شرك الله
# Generated Caption: لا شرك الله
# WER: 0.0
#
# True Caption: الله اكبر
# Generated Caption: الله اكبر
# WER: 0.0
#
# True Caption: السلام عليكم رحمة الله بركة
# Generated Caption: السلام عليكم رحمة الله بركة
# WER: 0.0
#
# Average WER on the Train Set: 0.0018726591760299626

# %% [markdown]
# ### Average WER on the Train Set: 0.0018726591760299626
